# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy


# Import the time library 
import time


# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Create counters.
record_count = 1
set_count = 1



# Create an empty list to hold the weather data.
city_WeatherPy_Data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]

        
       
        
        # Append the city information into city_data list.
        city_WeatherPy_Data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | oussouye
# Processing Record 4 of Set 1 | awjilah
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | tilichiki
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | ati
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | partizanskoye
# Processing Record 12 of Set 1 | mascote
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | sao joao da barra
# Processing Record 15 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | oranjemund
# Processing Record 19 of Set 1 | waipawa
# Processing Record 20 of Set 1 | moose factory
# Processing Record 21 of Set 1 | veinticinco de mayo
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | namatanai
# Processing Record 25 of Set 1 | chernitsyno
# Processing Record 26 of Set 1 | marawi
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | shetpe
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | tura
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | belyy yar
# Processing Record 39 of Set 1 | tocopilla
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | chala
# Processing Record 42 of Set 1 | voznesenye
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | pozo colorado
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | batagay-alyta
# Processing Record 4 of Set 2 | setermoen
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | atlantic city
# Processing Record 7 of Set 2 | grand-santi
# Processing Record 8 of Set 2 | palmas bellas
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | port hardy
# Processing Record 11 of Set 2 | camana
# Processing Record 12 of Set 2 | arona
# Processing Record 13 of Set 2 | touros
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | san fernando
# Processing Record 16 of Set 2 | broome
# Processing Record 17 of Set 2 | beira
# Processing Record 18 of Set 2 | kavaratti
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | milkovo
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | axim
# Processing Record 23 of Set 2 | maceio
# Processing Record 24 of Set 2 | linapacan
# City not found. Skipping...
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | charagua
# Processing Record 28 of Set 2 | rossosh
# Processing Record 29 of Set 2 | surt
# Processing Record 30 of Set 2 | krumovgrad
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | katghora
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | road town
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | sendhwa
# Processing Record 38 of Set 2 | yamada
# Processing Record 39 of Set 2 | fukue
# Processing Record 40 of Set 2 | caravelas
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | colares
# Processing Record 44 of Set 2 | itarema
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | tikrit
# Processing Record 49 of Set 2 | quepos
# Processing Record 50 of Set 2 | san patricio
# Processing Record 1 of Set 3 | vila franca do campo
# Processing Record 2 of Set 3 | buraydah
# Processing Record 3 of Set 3 | honiara
# Processing Record 4 of Set 3 | welkom
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | la paz
# Processing Record 7 of Set 3 | kokstad
# Processing Record 8 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | thinadhoo
# Processing Record 11 of Set 3 | luderitz
# Processing Record 12 of Set 3 | high level
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | luanda
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | the valley
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | hemsedal
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | tigil
# Processing Record 22 of Set 3 | lieksa
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | balsas
# Processing Record 26 of Set 3 | kerzhenets
# City not found. Skipping...
# Processing Record 27 of Set 3 | chimbote
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | ranong
# Processing Record 31 of Set 3 | falun
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | vrangel
# Processing Record 34 of Set 3 | macklin
# Processing Record 35 of Set 3 | norden
# Processing Record 36 of Set 3 | gamba
# Processing Record 37 of Set 3 | laguna
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | marienburg
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | yerbogachen
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | kayerkan
# Processing Record 45 of Set 3 | lavrentiya
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | pa sang
# Processing Record 48 of Set 3 | atherton
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | nikki
# Processing Record 1 of Set 4 | freetown
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | padang
# Processing Record 5 of Set 4 | barra dos coqueiros
# Processing Record 6 of Set 4 | a
# City not found. Skipping...
# Processing Record 7 of Set 4 | namanga
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | beloha
# Processing Record 10 of Set 4 | bandarbeyla
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | amlagora
# Processing Record 13 of Set 4 | at-bashi
# Processing Record 14 of Set 4 | borodino
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | sivas
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | coahuayana
# Processing Record 20 of Set 4 | hay river
# Processing Record 21 of Set 4 | christchurch
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | sayyan
# Processing Record 24 of Set 4 | kasongo-lunda
# Processing Record 25 of Set 4 | richards bay
# Processing Record 26 of Set 4 | igrim
# Processing Record 27 of Set 4 | sobolevo
# Processing Record 28 of Set 4 | terrace
# Processing Record 29 of Set 4 | jaciara
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | opunake
# Processing Record 32 of Set 4 | bethel
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | borovsk
# Processing Record 35 of Set 4 | gravdal
# Processing Record 36 of Set 4 | monticello
# Processing Record 37 of Set 4 | pangkalanbuun
# Processing Record 38 of Set 4 | tumaco
# Processing Record 39 of Set 4 | saint-pierre
# Processing Record 40 of Set 4 | alice
# Processing Record 41 of Set 4 | plaza de caisan
# Processing Record 42 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 43 of Set 4 | pedernales
# Processing Record 44 of Set 4 | homer
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | panguna
# Processing Record 47 of Set 4 | ayan
# Processing Record 48 of Set 4 | sur
# Processing Record 49 of Set 4 | primorsk
# Processing Record 50 of Set 4 | bardsir
# Processing Record 1 of Set 5 | katsuura
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | nueva helvecia
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | yinchuan
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | yellowknife
# Processing Record 9 of Set 5 | faanui
# Processing Record 10 of Set 5 | mezhdurechensk
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | morgan city
# Processing Record 14 of Set 5 | kieta
# Processing Record 15 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 5 | north bend
# Processing Record 17 of Set 5 | tiznit
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | timmins
# Processing Record 20 of Set 5 | porto torres
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | san cristobal
# Processing Record 23 of Set 5 | solnechnyy
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | bhabua
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | huarmey
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | chililabombwe
# Processing Record 31 of Set 5 | bulaevo
# Processing Record 32 of Set 5 | abbeville
# Processing Record 33 of Set 5 | cayenne
# Processing Record 34 of Set 5 | port alfred
# Processing Record 35 of Set 5 | borba
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | concarneau
# Processing Record 38 of Set 5 | noumea
# Processing Record 39 of Set 5 | zhob
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | zabol
# Processing Record 42 of Set 5 | emilio carranza
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | katete
# Processing Record 46 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 5 | bitung
# Processing Record 50 of Set 5 | port hedland
# Processing Record 1 of Set 6 | cookshire
# City not found. Skipping...
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | karonga
# Processing Record 5 of Set 6 | chabahar
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | porto santo
# Processing Record 8 of Set 6 | ayni
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | terra santa
# Processing Record 11 of Set 6 | puerto escondido
# Processing Record 12 of Set 6 | carauari
# Processing Record 13 of Set 6 | fortuna
# Processing Record 14 of Set 6 | rimbey
# Processing Record 15 of Set 6 | chimoio
# Processing Record 16 of Set 6 | khorramshahr
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | okha
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | aykhal
# Processing Record 21 of Set 6 | oleksandrivka
# Processing Record 22 of Set 6 | vestmannaeyjar
# Processing Record 23 of Set 6 | severnoye
# Processing Record 24 of Set 6 | berlevag
# Processing Record 25 of Set 6 | nuuk
# Processing Record 26 of Set 6 | tefe
# Processing Record 27 of Set 6 | kattivakkam
# Processing Record 28 of Set 6 | magistralnyy
# Processing Record 29 of Set 6 | coquimbo
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | rundu
# Processing Record 32 of Set 6 | atasu
# Processing Record 33 of Set 6 | tamandare
# Processing Record 34 of Set 6 | hurghada
# Processing Record 35 of Set 6 | carlos antonio lopez
# Processing Record 36 of Set 6 | chara
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | semey
# Processing Record 40 of Set 6 | denpasar
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | malkangiri
# Processing Record 43 of Set 6 | puerto del rosario
# Processing Record 44 of Set 6 | malinyi
# Processing Record 45 of Set 6 | filingue
# Processing Record 46 of Set 6 | pahrump
# Processing Record 47 of Set 6 | belaya gora
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | karratha
# Processing Record 50 of Set 6 | menongue
# Processing Record 1 of Set 7 | esik
# Processing Record 2 of Set 7 | batemans bay
# Processing Record 3 of Set 7 | portland
# Processing Record 4 of Set 7 | saint-philippe
# Processing Record 5 of Set 7 | sorland
# Processing Record 6 of Set 7 | sheksna
# Processing Record 7 of Set 7 | sabzevar
# Processing Record 8 of Set 7 | tangwani
# Processing Record 9 of Set 7 | camacupa
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | sagua la grande
# Processing Record 14 of Set 7 | ilulissat
# Processing Record 15 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 7 | coos bay
# Processing Record 17 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 7 | springdale
# Processing Record 19 of Set 7 | vondrozo
# Processing Record 20 of Set 7 | hambantota
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | koumra
# Processing Record 23 of Set 7 | norman
# Processing Record 24 of Set 7 | abu zabad
# Processing Record 25 of Set 7 | ternate
# Processing Record 26 of Set 7 | provideniya
# Processing Record 27 of Set 7 | olinda
# Processing Record 28 of Set 7 | mullheim
# Processing Record 29 of Set 7 | bud
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | voskresenskoye
# Processing Record 32 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 7 | lazaro cardenas
# Processing Record 34 of Set 7 | chernyshevskiy
# Processing Record 35 of Set 7 | port blair
# Processing Record 36 of Set 7 | harbour breton
# Processing Record 37 of Set 7 | jizan
# Processing Record 38 of Set 7 | placer
# Processing Record 39 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 7 | coihaique
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | ulaanbaatar
# Processing Record 43 of Set 7 | sabang
# Processing Record 44 of Set 7 | sibu
# Processing Record 45 of Set 7 | parkes
# Processing Record 46 of Set 7 | digha
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | port hawkesbury
# Processing Record 49 of Set 7 | vasilsursk
# Processing Record 50 of Set 7 | ballina
# Processing Record 1 of Set 8 | iquitos
# Processing Record 2 of Set 8 | thunder bay
# Processing Record 3 of Set 8 | tuntum
# Processing Record 4 of Set 8 | zaysan
# Processing Record 5 of Set 8 | lunen
# Processing Record 6 of Set 8 | williams lake
# Processing Record 7 of Set 8 | chillicothe
# Processing Record 8 of Set 8 | gat
# Processing Record 9 of Set 8 | neiafu
# Processing Record 10 of Set 8 | wanaka
# Processing Record 11 of Set 8 | ukiah
# Processing Record 12 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 8 | mersing
# Processing Record 14 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 8 | rodnykove
# Processing Record 17 of Set 8 | green river
# Processing Record 18 of Set 8 | oktyabrskiy
# Processing Record 19 of Set 8 | quesnel
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | fredericton
# Processing Record 23 of Set 8 | zuya
# Processing Record 24 of Set 8 | sao miguel do araguaia
# Processing Record 25 of Set 8 | umm lajj
# Processing Record 26 of Set 8 | costinesti
# Processing Record 27 of Set 8 | karabulak
# Processing Record 28 of Set 8 | lakhimpur
# Processing Record 29 of Set 8 | dunedin
# Processing Record 30 of Set 8 | sidi qasim
# City not found. Skipping...
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | gweru
# Processing Record 33 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 8 | rio grande
# Processing Record 35 of Set 8 | araguaina
# Processing Record 36 of Set 8 | paignton
# Processing Record 37 of Set 8 | viseu
# Processing Record 38 of Set 8 | labrea
# Processing Record 39 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 8 | banjar
# Processing Record 42 of Set 8 | urengoy
# Processing Record 43 of Set 8 | alofi
# Processing Record 44 of Set 8 | mount gambier
# Processing Record 45 of Set 8 | zatoka
# Processing Record 46 of Set 8 | agadez
# Processing Record 47 of Set 8 | paranavai
# Processing Record 48 of Set 8 | raudeberg
# Processing Record 49 of Set 8 | san joaquin
# Processing Record 50 of Set 8 | scarborough
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | new glasgow
# Processing Record 3 of Set 9 | bayamo
# Processing Record 4 of Set 9 | benguela
# Processing Record 5 of Set 9 | vostok
# Processing Record 6 of Set 9 | borazjan
# Processing Record 7 of Set 9 | griffith
# Processing Record 8 of Set 9 | pandavapura
# Processing Record 9 of Set 9 | oriximina
# Processing Record 10 of Set 9 | aksarka
# Processing Record 11 of Set 9 | kita
# Processing Record 12 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 9 | havre-saint-pierre
# Processing Record 14 of Set 9 | nikolskoye
# Processing Record 15 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 9 | oktyabrskoye
# Processing Record 17 of Set 9 | tezu
# Processing Record 18 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 9 | vangaindrano
# Processing Record 20 of Set 9 | sistranda
# Processing Record 21 of Set 9 | demidov
# Processing Record 22 of Set 9 | bauchi
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | pangai
# Processing Record 25 of Set 9 | kollam
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | korla
# Processing Record 28 of Set 9 | abu dhabi
# Processing Record 29 of Set 9 | bhaderwah
# Processing Record 30 of Set 9 | severo-kurilsk
# Processing Record 31 of Set 9 | roznava
# Processing Record 32 of Set 9 | karangampel
# Processing Record 33 of Set 9 | emba
# Processing Record 34 of Set 9 | erzincan
# Processing Record 35 of Set 9 | krasnoarmeysk
# Processing Record 36 of Set 9 | ourossogui
# Processing Record 37 of Set 9 | iwanai
# Processing Record 38 of Set 9 | dudinka
# Processing Record 39 of Set 9 | tecoanapa
# Processing Record 40 of Set 9 | shepetivka
# Processing Record 41 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 9 | codrington
# Processing Record 43 of Set 9 | ryotsu
# Processing Record 44 of Set 9 | koumac
# Processing Record 45 of Set 9 | maesteg
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | nogliki
# Processing Record 48 of Set 9 | chacaltianguis
# Processing Record 49 of Set 9 | oga
# Processing Record 50 of Set 9 | ulaangom
# Processing Record 1 of Set 10 | ipora
# Processing Record 2 of Set 10 | katima mulilo
# Processing Record 3 of Set 10 | praia da vitoria
# Processing Record 4 of Set 10 | maumere
# Processing Record 5 of Set 10 | staryy nadym
# Processing Record 6 of Set 10 | orsk
# Processing Record 7 of Set 10 | birin
# Processing Record 8 of Set 10 | stip
# City not found. Skipping...
# Processing Record 9 of Set 10 | ye
# City not found. Skipping...
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | tlacote el bajo
# Processing Record 12 of Set 10 | mokhsogollokh
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | nikolayevka
# Processing Record 15 of Set 10 | bairiki
# Processing Record 16 of Set 10 | karauli
# Processing Record 17 of Set 10 | isangel
# Processing Record 18 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 10 | houlton
# Processing Record 20 of Set 10 | pangnirtung
# Processing Record 21 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 10 | mahebourg
# Processing Record 25 of Set 10 | rio gallegos
# Processing Record 26 of Set 10 | saint-joseph
# Processing Record 27 of Set 10 | ghogha
# Processing Record 28 of Set 10 | cabedelo
# Processing Record 29 of Set 10 | sao filipe
# Processing Record 30 of Set 10 | popondetta
# Processing Record 31 of Set 10 | dabola
# Processing Record 32 of Set 10 | miraflores
# Processing Record 33 of Set 10 | komsomolskiy
# Processing Record 34 of Set 10 | gbarnga
# Processing Record 35 of Set 10 | katobu
# Processing Record 36 of Set 10 | roald
# Processing Record 37 of Set 10 | zaragoza
# Processing Record 38 of Set 10 | naze
# Processing Record 39 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 10 | baoqing
# Processing Record 41 of Set 10 | yuzhnyy
# Processing Record 42 of Set 10 | porbandar
# Processing Record 43 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 44 of Set 10 | bilma
# Processing Record 45 of Set 10 | nagar karnul
# Processing Record 46 of Set 10 | chapais
# Processing Record 47 of Set 10 | luganville
# Processing Record 48 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 10 | kapit
# Processing Record 50 of Set 10 | taketa
# Processing Record 1 of Set 11 | kelo
# Processing Record 2 of Set 11 | palmer
# Processing Record 3 of Set 11 | flinders
# Processing Record 4 of Set 11 | zlobin
# Processing Record 5 of Set 11 | comodoro rivadavia
# Processing Record 6 of Set 11 | amuntai
# Processing Record 7 of Set 11 | linqu
# Processing Record 8 of Set 11 | anage
# Processing Record 9 of Set 11 | salto de agua
# Processing Record 10 of Set 11 | ahipara
# Processing Record 11 of Set 11 | metro
# Processing Record 12 of Set 11 | mocuba
# Processing Record 13 of Set 11 | vardo
# Processing Record 14 of Set 11 | esso
# Processing Record 15 of Set 11 | lewisporte
# Processing Record 16 of Set 11 | gorontalo
# Processing Record 17 of Set 11 | kaz
# Processing Record 18 of Set 11 | camalu
# Processing Record 19 of Set 11 | malinovoye ozero
# Processing Record 20 of Set 11 | sioux lookout
# Processing Record 21 of Set 11 | machala
# Processing Record 22 of Set 11 | cukai
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | jardim
# Processing Record 25 of Set 11 | yeppoon
# Processing Record 26 of Set 11 | meulaboh
# Processing Record 27 of Set 11 | campestre
# Processing Record 28 of Set 11 | guane
# Processing Record 29 of Set 11 | tommot
# Processing Record 30 of Set 11 | buchanan
# Processing Record 31 of Set 11 | baykit
# Processing Record 32 of Set 11 | sambava
# Processing Record 33 of Set 11 | the pas
# Processing Record 34 of Set 11 | fairbanks
# Processing Record 35 of Set 11 | gongzhuling
# Processing Record 36 of Set 11 | minsk
# Processing Record 37 of Set 11 | saryozek
# Processing Record 38 of Set 11 | florence
# Processing Record 39 of Set 11 | weener
# Processing Record 40 of Set 11 | varhaug
# Processing Record 41 of Set 11 | socorro
# Processing Record 42 of Set 11 | chifeng
# Processing Record 43 of Set 11 | puerto lleras
# Processing Record 44 of Set 11 | jinji
# Processing Record 45 of Set 11 | miyako
# Processing Record 46 of Set 11 | abra de ilog
# Processing Record 47 of Set 11 | trinidad
# Processing Record 48 of Set 11 | kahului
# Processing Record 49 of Set 11 | mosquera
# Processing Record 50 of Set 11 | lorengau
# Processing Record 1 of Set 12 | westport
# Processing Record 2 of Set 12 | hami
# Processing Record 3 of Set 12 | sretensk
# Processing Record 4 of Set 12 | bara
# Processing Record 5 of Set 12 | biak
# Processing Record 6 of Set 12 | juneau
# Processing Record 7 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 12 | erenhot
# Processing Record 9 of Set 12 | quelimane
# Processing Record 10 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | pombas
# Processing Record 12 of Set 12 | ribeira brava
# Processing Record 13 of Set 12 | dulce grande
# Processing Record 14 of Set 12 | ayna
# Processing Record 15 of Set 12 | robertson
# Processing Record 16 of Set 12 | bonnyville
# Processing Record 17 of Set 12 | laela
# Processing Record 18 of Set 12 | sept-iles
# Processing Record 19 of Set 12 | parana
# Processing Record 20 of Set 12 | ust-kuyga
# Processing Record 21 of Set 12 | norman wells
# Processing Record 22 of Set 12 | punta umbria
# Processing Record 23 of Set 12 | nhulunbuy
# Processing Record 24 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 12 | zhezkazgan
# Processing Record 26 of Set 12 | kommunisticheskiy
# Processing Record 27 of Set 12 | novoorsk
# Processing Record 28 of Set 12 | moron
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | lakes entrance
# Processing Record 31 of Set 12 | gazojak
# Processing Record 32 of Set 12 | derzhavinsk
# Processing Record 33 of Set 12 | saint peter
# Processing Record 34 of Set 12 | troitskoye
# Processing Record 35 of Set 12 | klaksvik
# Processing Record 36 of Set 12 | tarbagatay
# Processing Record 37 of Set 12 | slupca
# Processing Record 38 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 12 | bongandanga
# Processing Record 40 of Set 12 | bagan
# Processing Record 41 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 12 | mangan
# Processing Record 43 of Set 12 | iskateley
# Processing Record 44 of Set 12 | qasigiannguit
# Processing Record 45 of Set 12 | talnakh
# Processing Record 46 of Set 12 | mahajanga
# Processing Record 47 of Set 12 | vanimo
# Processing Record 48 of Set 12 | laguna de perlas
# Processing Record 49 of Set 12 | niono
# Processing Record 50 of Set 12 | mehamn
# Processing Record 1 of Set 13 | aasiaat
# Processing Record 2 of Set 13 | aquiraz
# Processing Record 3 of Set 13 | blagoveshchenka
# Processing Record 4 of Set 13 | andros town
# Processing Record 5 of Set 13 | santa vitoria do palmar
# Processing Record 6 of Set 13 | north battleford
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | ludvika
# Processing Record 9 of Set 13 | mao
# Processing Record 10 of Set 13 | nago
# Processing Record 11 of Set 13 | manono
# Processing Record 12 of Set 13 | burnie
# Processing Record 13 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 13 | khani
# Processing Record 15 of Set 13 | callaway
# Processing Record 16 of Set 13 | launceston
# Processing Record 17 of Set 13 | margate
# Processing Record 18 of Set 13 | necochea
# Processing Record 19 of Set 13 | pasni
# Processing Record 20 of Set 13 | pevek
# Processing Record 21 of Set 13 | zhigansk
# Processing Record 22 of Set 13 | porirua
# Processing Record 23 of Set 13 | moree
# Processing Record 24 of Set 13 | papillion
# Processing Record 25 of Set 13 | samarai
# Processing Record 26 of Set 13 | beyneu
# Processing Record 27 of Set 13 | carutapera
# Processing Record 28 of Set 13 | salinopolis
# Processing Record 29 of Set 13 | buala
# Processing Record 30 of Set 13 | vegreville
# Processing Record 31 of Set 13 | bereznik
# Processing Record 32 of Set 13 | bukoba
# Processing Record 33 of Set 13 | niagara falls
# Processing Record 34 of Set 13 | porto novo
# Processing Record 35 of Set 13 | ouesso
# Processing Record 36 of Set 13 | hanko
# Processing Record 37 of Set 13 | colonia
# Processing Record 38 of Set 13 | chicama
# Processing Record 39 of Set 13 | canchungo
# Processing Record 40 of Set 13 | bosaso
# Processing Record 41 of Set 13 | vidim
# Processing Record 42 of Set 13 | ixtapa
# Processing Record 43 of Set 13 | avera
# Processing Record 44 of Set 13 | oranjestad
# Processing Record 45 of Set 13 | salem
# Processing Record 46 of Set 13 | vilyuysk
# Processing Record 47 of Set 13 | bogalusa
# Processing Record 48 of Set 13 | praia
# Processing Record 49 of Set 13 | pierre
# Processing Record 50 of Set 13 | san quintin
# Processing Record 1 of Set 14 | maneadero
# Processing Record 2 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 3 of Set 14 | elliot
# Processing Record 4 of Set 14 | rawson
# Processing Record 5 of Set 14 | poum
# Processing Record 6 of Set 14 | mutoko
# Processing Record 7 of Set 14 | del rio
# Processing Record 8 of Set 14 | hastings
# Processing Record 9 of Set 14 | broken hill
# Processing Record 10 of Set 14 | san policarpo
# Processing Record 11 of Set 14 | orlik
# Processing Record 12 of Set 14 | mbandaka
# Processing Record 13 of Set 14 | auki
# Processing Record 14 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 14 | nanma
# Processing Record 16 of Set 14 | aksu
# Processing Record 17 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 18 of Set 14 | koslan
# Processing Record 19 of Set 14 | hovd
# Processing Record 20 of Set 14 | wolfville
# Processing Record 21 of Set 14 | langxiang
# Processing Record 22 of Set 14 | colombo
# Processing Record 23 of Set 14 | kemijarvi
# Processing Record 24 of Set 14 | talara
# Processing Record 25 of Set 14 | antalaha
# Processing Record 26 of Set 14 | florida
# Processing Record 27 of Set 14 | trairi
# Processing Record 28 of Set 14 | culleredo
# Processing Record 29 of Set 14 | pringsewu
# Processing Record 30 of Set 14 | saint-leu
# Processing Record 31 of Set 14 | barcelos
# Processing Record 32 of Set 14 | udachnyy
# Processing Record 33 of Set 14 | pak phanang
# Processing Record 34 of Set 14 | adamovka
# Processing Record 35 of Set 14 | odate
# Processing Record 36 of Set 14 | viedma
# Processing Record 37 of Set 14 | eureka
# Processing Record 38 of Set 14 | roebourne
# Processing Record 39 of Set 14 | rancho cucamonga
# Processing Record 40 of Set 14 | kiunga
# Processing Record 41 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 14 | manica
# Processing Record 43 of Set 14 | tchaourou
# Processing Record 44 of Set 14 | krasnyy yar
# Processing Record 45 of Set 14 | tessalit
# Processing Record 46 of Set 14 | quang ngai
# Processing Record 47 of Set 14 | bubaque
# Processing Record 48 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 14 | deputatskiy
# Processing Record 50 of Set 14 | garoua boulai
# Processing Record 1 of Set 15 | stornoway
# Processing Record 2 of Set 15 | southbridge
# Processing Record 3 of Set 15 | golaghat
# Processing Record 4 of Set 15 | vila velha
# Processing Record 5 of Set 15 | ingham
# Processing Record 6 of Set 15 | nelson
# Processing Record 7 of Set 15 | begoro
# Processing Record 8 of Set 15 | peniche
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | paamiut
# Processing Record 11 of Set 15 | igarka
# Processing Record 12 of Set 15 | woodward
# Processing Record 13 of Set 15 | kalanwali
# Processing Record 14 of Set 15 | valencia
# Processing Record 15 of Set 15 | taoudenni
# Processing Record 16 of Set 15 | khorixas
# Processing Record 17 of Set 15 | tautira
# Processing Record 18 of Set 15 | charters towers
# Processing Record 19 of Set 15 | havoysund
# Processing Record 20 of Set 15 | guelengdeng
# City not found. Skipping...
# Processing Record 21 of Set 15 | daru
# Processing Record 22 of Set 15 | balikpapan
# Processing Record 23 of Set 15 | sola
# Processing Record 24 of Set 15 | conceicao da barra
# Processing Record 25 of Set 15 | waddan
# Processing Record 26 of Set 15 | kafanchan
# Processing Record 27 of Set 15 | kadyy
# Processing Record 28 of Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 29 of Set 15 | juegang
# Processing Record 30 of Set 15 | vuktyl
# Processing Record 31 of Set 15 | labuhan
# Processing Record 32 of Set 15 | gryazi
# Processing Record 33 of Set 15 | chapleau
# Processing Record 34 of Set 15 | felanitx
# Processing Record 35 of Set 15 | marfino
# Processing Record 36 of Set 15 | dong hoi
# Processing Record 37 of Set 15 | arbazh
# Processing Record 38 of Set 15 | marathon
# Processing Record 39 of Set 15 | kropotkin
# Processing Record 40 of Set 15 | gombong
# Processing Record 41 of Set 15 | ascension
# Processing Record 42 of Set 15 | jinka
# Processing Record 43 of Set 15 | rjukan
# Processing Record 44 of Set 15 | maguri-racatau
# City not found. Skipping...
# Processing Record 45 of Set 15 | sawai madhopur
# Processing Record 46 of Set 15 | qaqortoq
# Processing Record 47 of Set 15 | doha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df= pd.DataFrame(city_WeatherPy_Data)
WeatherPy_Database_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea      PF -23.1203 -134.9692     73.35        77           1
# 1       Oussouye      SN  12.4850  -16.5469     80.69        84         100
# 2        Awjilah      LY  29.1081   21.2869     80.51        47           0
# 3    Tuktoyaktuk      CA  69.4541 -133.0374     48.20        81          75
# 4      Tilichiki      RU  60.4667  166.1000     54.45        93         100
# 5        Ushuaia      AR -54.8000  -68.3000     37.06        87         100
# 6         Albany      US  42.6001  -73.9662     78.64        44          27
# 7            Ati      TD  13.2154   18.3353     79.92        74          97
# 8          Bluff      NZ -46.6000  168.3333     50.81        74          88
# 9  Partizanskoye      RU  55.5006   94.3900     50.74        90           9
#
#    Wind Speed weather Description
# 0       18.86           clear sky
# 1        5.77     overcast clouds
# 2        7.56           clear sky
# 3       17.27       broken clouds
# 4        7.20     overcast clouds
# 5       12.66          light rain
# 6        4.18    scattered clouds
# 7        5.91          light rain
# 8        5.68     overcast clouds
# 9        8.12           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database_df.to_csv(output_data_file, index_label="City_ID")
